# %%
GEMINI_API_KEY = dbutils.secrets.get(scope="Databricks_Scope", key="GEMINI_API_KEY")

# %%
from google import genai

client = genai.Client(api_key=GEMINI_API_KEY)

response = client.models.generate_content(
    model="gemini-2.5-flash",
    contents="what is the difference between GenAI and LLM?",
)

print(response.text)

# %%
from google import genai

client = genai.Client(api_key=GEMINI_API_KEY)

response = client.models.generate_content_stream(
    model="gemini-2.5-flash",
    contents=["Provide the expense ration of all india ETFs in a json/dict"]
)
for chunk in response:
    print(chunk.text, end="")

# %% [markdown]
# Getting an absolutely exhaustive, real-time list of *all* Indian ETFs with their exact expense ratios (Total Expense Ratio - TER) is challenging because:
# 1.  **Dynamic Nature:** Expense ratios can change.
# 2.  **New Launches:** New ETFs are launched regularly.
# 3.  **Data Sources:** Official sources like AMFI provide data, but compiling it into a single, clean JSON can be tedious. Financial portals (Value Research, Moneycontrol, etc.) are often a good consolidated source but might have slight delays.
#
# However, I can provide a comprehensive list of major and popular India-listed ETFs across various categories with their approximate expense ratios as of **early May 2024**. Always verify the latest TER directly from the respective AMC's website or fund fact sheet before making any investment decisions.
#
# Here's the data in JSON format:
#
# ```json
# {
#   "last_updated": "2024-05-08",
#   "disclaimer": "Expense ratios (Total Expense Ratio - TER) are subject to change by the respective AMCs. This data is indicative and based on publicly available information as of the last update. Always verify the latest TER directly from the AMC's website or fund fact sheet before investing. This list aims to be comprehensive for major Indian ETFs but may not include every single niche or newly launched ETF.",
#   "etfs": [
#     {
#       "name": "Nippon India ETF Nifty 50 BeES",
#       "amc": "Nippon India Mutual Fund",
#       "category": "Equity - Large Cap Index",
#       "expense_ratio": 0.05
#     },
#     {
#       "name": "SBI Nifty 50 ETF",
#       "amc": "SBI Mutual Fund",
#       "category": "Equity - Large Cap Index",
#       "expense_ratio": 0.05
#     },
#     {
#       "name": "ICICI Prudential Nifty 50 ETF",
#       "amc": "ICICI Prudential Mutual Fund",
#       "category": "Equity - Large Cap Index",
#       "expense_ratio": 0.05
#     },
#     {
#       "name": "UTI Nifty 50 ETF",
#       "amc": "UTI Mutual Fund",
#       "category": "Equity - Large Cap Index",
#       "expense_ratio": 0.05
#     },
#     {
#       "name": "HDFC Nifty 50 ETF",
#       "amc": "HDFC Mutual Fund",
#       "category": "Equity - Large Cap Index",
#       "expense_ratio": 0.05
#     },
#     {
#       "name": "Motilal Oswal Nifty 50 ETF",
#       "amc": "Motilal Oswal Mutual Fund",
#       "category": "Equity - Large Cap Index",
#       "expense_ratio": 0.05
#     },
#     {
#       "name": "Nippon India ETF Nifty Next 50 Junior BeES",
#       "amc": "Nippon India Mutual Fund",
#       "category": "Equity - Large & Mid Cap Index",
#       "expense_ratio": 0.16
#     },
#     {
#       "name": "ICICI Prudential Nifty Next 50 ETF",
#       "amc": "ICICI Prudential Mutual Fund",
#       "category": "Equity - Large & Mid Cap Index",
#       "expense_ratio": 0.16
#     },
#     {
#       "name": "SBI Nifty Next 50 ETF",
#       "amc": "SBI Mutual Fund",
#       "category": "Equity - Large & Mid Cap Index",
#       "expense_ratio": 0.16
#     },
#     {
#       "name": "Nippon India ETF Nifty Bank BeES",
#       "amc": "Nippon India Mutual Fund",
#       "category": "Equity - Sectoral Index (Banking)",
#       "expense_ratio": 0.15
#     },
#     {
#       "name": "ICICI Prudential Nifty Bank ETF",
#       "amc": "ICICI Prudential Mutual Fund",
#       "category": "Equity - Sectoral Index (Banking)",
#       "expense_ratio": 0.15
#     },
#     {
#       "name": "Kotak Nifty Bank ETF",
#       "amc": "Kotak Mutual Fund",
#       "category": "Equity - Sectoral Index (Banking)",
#       "expense_ratio": 0.15
#     },
#     {
#       "name": "Motilal Oswal Nifty Midcap 100 ETF",
#       "amc": "Motilal Oswal Mutual Fund",
#       "category": "Equity - Mid Cap Index",
#       "expense_ratio": 0.20
#     },
#     {
#       "name": "SBI Nifty Midcap 150 ETF",
#       "amc": "SBI Mutual Fund",
#       "category": "Equity - Mid Cap Index",
#       "expense_ratio": 0.20
#     },
#     {
#       "name": "Edelweiss Nifty Midcap 100 ETF",
#       "amc": "Edelweiss Mutual Fund",
#       "category": "Equity - Mid Cap Index",
#       "expense_ratio": 0.20
#     },
#     {
#       "name": "Mirae Asset Nifty Smallcap 250 ETF",
#       "amc": "Mirae Asset Mutual Fund",
#       "category": "Equity - Small Cap Index",
#       "expense_ratio": 0.40
#     },
#     {
#       "name": "HDFC Nifty Smallcap 250 ETF",
#       "amc": "HDFC Mutual Fund",
#       "category": "Equity - Small Cap Index",
#       "expense_ratio": 0.40
#     },
#     {
#       "name": "Nippon India ETF Gold BeES",
#       "amc": "Nippon India Mutual Fund",
#       "category": "Commodity - Gold",
#       "expense_ratio": 0.78
#     },
#     {
#       "name": "ICICI Prudential Gold ETF",
#       "amc": "ICICI Prudential Mutual Fund",
#       "category": "Commodity - Gold",
#       "expense_ratio": 0.50
#     },
#     {
#       "name": "HDFC Gold ETF",
#       "amc": "HDFC Mutual Fund",
#       "category": "Commodity - Gold",
#       "expense_ratio": 0.53
#     },
#     {
#       "name": "SBI Gold ETF",
#       "amc": "SBI Mutual Fund",
#       "category": "Commodity - Gold",
#       "expense_ratio": 0.65
#     },
#     {
#       "name": "Axis Gold ETF",
#       "amc": "Axis Mutual Fund",
#       "category": "Commodity - Gold",
#       "expense_ratio": 0.35
#     },
#     {
#       "name": "ICICI Prudential Silver ETF",
#       "amc": "ICICI Prudential Mutual Fund",
#       "category": "Commodity - Silver",
#       "expense_ratio": 0.40
#     },
#     {
#       "name": "Nippon India Silver ETF",
#       "amc": "Nippon India Mutual Fund",
#       "category": "Commodity - Silver",
#       "expense_ratio": 0.40
#     },
#     {
#       "name": "Aditya Birla Sun Life Nifty IT ETF",
#       "amc": "Aditya Birla Sun Life Mutual Fund",
#       "category": "Equity - Sectoral Index (IT)",
#       "expense_ratio": 0.30
#     },
#     {
#       "name": "ICICI Prudential Nifty IT ETF",
#       "amc": "ICICI Prudential Mutual Fund",
#       "category": "Equity - Sectoral Index (IT)",
#       "expense_ratio": 0.30
#     },
#     {
#       "name": "Kotak Nifty Pharma ETF",
#       "amc": "Kotak Mutual Fund",
#       "category": "Equity - Sectoral Index (Pharma)",
#       "expense_ratio": 0.30
#     },
#     {
#       "name": "Motilal Oswal NASDAQ 100 ETF",
#       "amc": "Motilal Oswal Mutual Fund",
#       "category": "Equity - International Index (US)",
#       "expense_ratio": 0.54
#     },
#     {
#       "name": "Mirae Asset S&P 500 Top 50 ETF",
#       "amc": "Mirae Asset Mutual Fund",
#       "category": "Equity - International Index (US)",
#       "expense_ratio": 0.50
#     },
#     {
#       "name": "Edelweiss Nifty 100 Quality 30 ETF",
#       "amc": "Edelweiss Mutual Fund",
#       "category": "Equity - Factor-based",
#       "expense_ratio": 0.35
#     },
#     {
#       "name": "Axis Nifty 500 ETF",
#       "amc": "Axis Mutual Fund",
#       "category": "Equity - Broad Market Index",
#       "expense_ratio": 0.20
#     },
#     {
#       "name": "Mirae Asset Nifty India Manufacturing ETF",
#       "amc": "Mirae Asset Mutual Fund",
#       "category": "Equity - Sectoral/Thematic",
#       "expense_ratio": 0.25
#     },
#     {
#       "name": "Kotak Nifty Infrastructure ETF",
#       "amc": "Kotak Mutual Fund",
#       "category": "Equity - Sectoral/Thematic",
#       "expense_ratio": 0.30
#     },
#     {
#       "name": "ICICI Prudential Nifty PSU Bank ETF",
#       "amc": "ICICI Prudential Mutual Fund",
#       "category": "Equity - Sectoral Index (PSU Banking)",
#       "expense_ratio": 0.30
#     },
#     {
#       "name": "Edelweiss Alpha Low Volatility 30 ETF",
#       "amc": "Edelweiss Mutual Fund",
#       "category": "Equity - Factor-based",
#       "expense_ratio": 0.35
#     },
#     {
#       "name": "Aditya Birla Sun Life Nifty Healthcare ETF",
#       "amc": "Aditya Birla Sun Life Mutual Fund",
#       "category": "Equity - Sectoral Index (Healthcare)",
#       "expense_ratio": 0.30
#     }
#   ]
# }
# ```

# %%
import subprocess
import sys
    
def install(package):
    subprocess.check_call([sys.executable, "-m", "pip", "install", package])
